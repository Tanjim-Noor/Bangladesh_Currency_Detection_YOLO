# %% [markdown]
# ---
#
# ## 📋 Diagnostic Tools
#
# The sections below contain diagnostic tools to help troubleshoot GPU/CUDA issues.

# %%
# Verify CUDA installation after kernel restart
import torch

print("🔍 Verifying PyTorch Installation:")
print("="*50)
print(f"PyTorch Version: {torch.__version__}")
print(f"CUDA Available: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"CUDA Version: {torch.version.cuda}")
    print(f"GPU Device: {torch.cuda.get_device_name(0)}")
    print(f"GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.1f} GB")
    print("\n✅ GPU is ready for training!")
else:
    print("\n⚠️ CUDA not detected. Please:")
    print("   1. Ensure NVIDIA drivers are installed")
    print("   2. Restart your kernel after installing PyTorch")
    print("   3. Check NVIDIA Control Panel to verify GPU is active")
print("="*50)
# Out:
# 🔍 Verifying PyTorch Installation:
# ==================================================
# PyTorch Version: 2.9.1+cu130
# CUDA Available: True
# CUDA Version: 13.0
# GPU Device: NVIDIA GeForce RTX 3080
# GPU Memory: 10.0 GB
#
# ✅ GPU is ready for training!
# ==================================================

# %%
# ⚠️ IMPORTANT: Install PyTorch with CUDA Support
# Run this cell to install PyTorch with CUDA 13.0 for your RTX 3080
# (Matches official PyTorch recommendation for Stable 2.9.1)

# Uninstall CPU-only version first
# !pip uninstall torch torchvision torchaudio -y -q

# Install PyTorch with CUDA 13.0 support (Latest Stable)
# !pip install torch torchvision --index-url https://download.pytorch.org/whl/cu130

print("✅ PyTorch with CUDA 13.0 support installed!")
print("\n⚠️ IMPORTANT: After installation, restart your kernel:")
print("   - Click 'Restart' button at the top")
print("   - Or: Kernel → Restart Kernel")
print("\nThen re-run all cells from the beginning.")
# Out:
# WARNING: Failed to remove contents in a temporary directory 'D:\Study\Ostad\11. Model Finetuning & Intro to Transformers\Assignment\venv\Lib\site-packages\~orch'.
# You can safely remove it manually.
# WARNING: Skipping torchaudio as it is not installed.
# Looking in indexes: https://download.pytorch.org/whl/cu130
# Collecting torch
#   Downloading https://download.pytorch.org/whl/cu130/torch-2.9.1%2Bcu130-cp313-cp313-win_amd64.whl.metadata (29 kB)
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/cu130/torchvision-0.24.1%2Bcu130-cp313-cp313-win_amd64.whl.metadata (6.1 kB)
# Requirement already satisfied: filelock in d:\study\ostad\11. model finetuning & intro to transformers\assignment\venv\lib\site-packages (from torch) (3.20.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\study\ostad\11. model finetuning & intro to transformers\assignment\venv\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in d:\study\ostad\11. model finetuning & intro to transformers\assignment\venv\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in d:\study\ostad\11. model finetuning & intro to transformers\assignment\venv\lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in d:\study\ostad\11. model finetuning & intro to transformers\assignment\venv\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in d:\study\ostad\11. model finetuning & intro to transformers\assignment\venv\lib\site-packages (from torch) (2025.12.0)
# Requirement already satisfied: setuptools in d:\study\ostad\11. model finetuning & intro to transformers\assignment\venv\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: numpy in d:\study\ostad\11. model finetuning & intro to transformers\assignment\venv\lib\site-packages (from torchvision) (2.2.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in d:\study\ostad\11. model finetuning & intro to transformers\assignment\venv\lib\site-packages (from torchvision) (12.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\study\ostad\11. model finetuning & intro to transformers\assignment\venv\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\study\ostad\11. model finetuning & intro to transformers\assignment\venv\lib\site-packages (from jinja2->torch) (3.0.3)
# Downloading https://download.pytorch.org/whl/cu130/torch-2.9.1%2Bcu130-cp313-cp313-win_amd64.whl (1862.1 MB)
#    ---------------------------------------- 0.0/1.9 GB ? eta -:--:--
#    ---------------------------------------- 0.0/1.9 GB 110.1 MB/s eta 0:00:17
#     --------------------------------------- 0.0/1.9 GB 112.5 MB/s eta 0:00:17
#    - -------------------------------------- 0.1/1.9 GB 113.1 MB/s eta 0:00:16
#    - -------------------------------------- 0.1/1.9 GB 113.5 MB/s eta 0:00:16
#    -- ------------------------------------- 0.1/1.9 GB 113.1 MB/s eta 0:00:16
#    -- ------------------------------------- 0.1/1.9 GB 113.4 MB/s eta 0:00:16
#    --- ------------------------------------ 0.2/1.9 GB 113.9 MB/s eta 0:00:15
#    --- ------------------------------------ 0.2/1.9 GB 113.4 MB/s eta 0:00:15
#    ---- ----------------------------------- 0.2/1.9 GB 113.4 MB/s eta 0:00:15
#    ---- ----------------------------------- 0.2/1.9 GB 114.1 MB/s eta 0:00:15
#    ----- ---------------------------------- 0.3/1.9 GB 113.7 MB/s eta 0:00:15
#    ----- ---------------------------------- 0.3/1.9 GB 114.6 MB/s eta 0:00:14
#    ------ --------------------------------- 0.3/1.9 GB 114.7 MB/s eta 0:00:14
#    ------ --------------------------------- 0.3/1.9 GB 114.5 MB/s eta 0:00:14
#    ------- -------------------------------- 0.3/1.9 GB 114.0 MB/s eta 0:00:14
#    ------- -------------------------------- 0.4/1.9 GB 114.7 MB/s eta 0:00:14
#    -------- ------------------------------- 0.4/1.9 GB 114.6 MB/s eta 0:00:13
#    -------- ------------------------------- 0.4/1.9 GB 114.2 MB/s eta 0:00:13
#    --------- ------------------------------ 0.4/1.9 GB 114.7 MB/s eta 0:00:13
#    --------- ------------------------------ 0.5/1.9 GB 114.4 MB/s eta 0:00:13
#    ---------- -----------------------------
5 MB/s eta 0:00:03
#    ---------------------------------- ----- 1.6/1.9 GB 114.5 MB/s eta 0:00:03
#    ---------------------------------- ----- 1.6/1.9 GB 114.5 MB/s eta 0:00:03
#    ----------------------------------- ---- 1.6/1.9 GB 114.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 1.7/1.9 GB 114.5 MB/s eta 0:00:02
#    ------------------------------------ --- 1.7/1.9 GB 114.5 MB/s eta 0:00:02
#    ------------------------------------ --- 1.7/1.9 GB 114.5 MB/s eta 0:00:02
#    ------------------------------------- -- 1.7/1.9 GB 114.5 MB/s eta 0:00:02
#    ------------------------------------- -- 1.8/1.9 GB 114.6 MB/s eta 0:00:01
#    -------------------------------------- - 1.8/1.9 GB 114.7 MB/s eta 0:00:01
#    -------------------------------------- - 1.8/1.9 GB 114.5 MB/s eta 0:00:01
#    ---------------------------------------  1.8/1.9 GB 115.0 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 GB 114.5 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 GB 114.5 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 GB 114.5 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 GB 114.5 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 GB 114.5 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 GB 114.5 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 GB 114.5 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 GB 114.5 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 GB 114.5 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 GB 114.5 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 GB 114.5 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 GB 114.5 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 GB 114.5 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 GB 114.5 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 GB 114.5 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 GB 114.5 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 GB 114.5 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 GB 114.5 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 GB 114.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 GB 44.7 MB/s  0:00:20
# Downloading https://download.pytorch.org/whl/cu130/torchvision-0.24.1%2Bcu130-cp313-cp313-win_amd64.whl (8.9 MB)
#    ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#    -------------------------------- ------- 7.3/8.9 MB 115.0 MB/s eta 0:00:01
#    ---------------------------------------- 8.9/8.9 MB 26.8 MB/s  0:00:00
# Installing collected packages: torch, torchvision
#
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
# ...
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    ---------------------------------------- 2/2 [torchvision]
#
# Successfully installed torch-2.9.1+cu130 torchvision-0.24.1+cu130
# ✅ PyTorch with CUDA 13.0 support installed!
#
# ⚠️ IMPORTANT: After installation, restart your kernel:
#    - Click 'Restart' button at the top
#    - Or: Kernel → Restart Kernel
#
# Then re-run all cells from the beginning.

# %% [markdown]
# # GPU & PyTorch Diagnostics
#
# This notebook contains diagnostic tools and setup instructions to troubleshoot GPU/CUDA configuration issues.
#
# ---
#
# ## 🔧 GPU Setup & Installation
#
# ### System Requirements
#
# **Good News**: If you have an **NVIDIA GeForce RTX 3080** or similar GPU - excellent for training!
#
# **Common Issue**: PyTorch installed without CUDA support (CPU-only version).
#
# **Solution**: Follow the installation steps below to install PyTorch with CUDA support.

# %% [markdown]
# ## 1. Python Environment Check
#
# Verify which Python environment Jupyter is using.

# %%
# 🔍 DIAGNOSTIC: Check which Python environment Jupyter is using
import sys
import os

print("🔍 Python Environment Diagnostics:")
print("="*60)
print(f"Python Executable: {sys.executable}")
print(f"Python Version: {sys.version.split()[0]}")
print(f"Python Path: {sys.prefix}")
print("\n📍 Sys.path (where Python looks for packages):")
for i, path in enumerate(sys.path[:5], 1):
    print(f"   {i}. {path}")

print("\n💡 Next Steps:")
print("   If the Python executable above is NOT in a virtual environment,")
print("   that's likely why CUDA isn't detected (packages installed elsewhere).")
print("="*60)
# Out:
# 🔍 Python Environment Diagnostics:
# ============================================================
# Python Executable: d:\Study\Ostad\11. Model Finetuning & Intro to Transformers\Assignment\venv\Scripts\python.exe
# Python Version: 3.13.11
# Python Path: d:\Study\Ostad\11. Model Finetuning & Intro to Transformers\Assignment\venv
#
# 📍 Sys.path (where Python looks for packages):
#    1. H:\Dev\Python\python313.zip
#    2. H:\Dev\Python\DLLs
#    3. H:\Dev\Python\Lib
#    4. H:\Dev\Python
#    5. d:\Study\Ostad\11. Model Finetuning & Intro to Transformers\Assignment\venv
#
# 💡 Next Steps:
#    If the Python executable above is NOT in a virtual environment,
#    that's likely why CUDA isn't detected (packages installed elsewhere).
# ============================================================

# %% [markdown]
# ## 2. PyTorch Installation Details
#
# Check PyTorch version, CUDA support, and system GPU configuration.

# %%
# 🔍 DIAGNOSTIC: Check PyTorch installation details
import subprocess
import sys

print("🔍 PyTorch Installation Details:")
print("="*60)

# Check if torch is installed
try:
    import torch
    print(f"✅ PyTorch is installed: {torch.__version__}")
    print(f"   CUDA Available: {torch.cuda.is_available()}")
    
    if torch.cuda.is_available():
        print(f"   CUDA Version (PyTorch): {torch.version.cuda}")
    else:
        print("   ⚠️ CUDA support NOT found in PyTorch installation")
        print("\n   This means PyTorch was installed WITHOUT CUDA support.")
        print("   The CPU-only version is currently installed.")
    
except ImportError:
    print("❌ PyTorch is NOT installed")

# Show detailed pip info for torch
print("\n📦 Pip Package Details:")
print("="*60)
result = subprocess.run([sys.executable, "-m", "pip", "show", "torch"], 
                       capture_output=True, text=True)
print(result.stdout)

# Check NVIDIA driver version
print("🖥️  System CUDA Check:")
print("="*60)
nvidia_smi = subprocess.run(["nvidia-smi"], capture_output=True, text=True)
if nvidia_smi.returncode == 0:
    # Extract CUDA version from nvidia-smi output
    lines = nvidia_smi.stdout.split('\n')
    for line in lines:
        if 'CUDA Version' in line:
            print(f"✅ {line.strip()}")
            break
else:
    print("⚠️ nvidia-smi not found or failed")

print("\n💡 Solution:")
print("   If CUDA is NOT available in PyTorch, you need to:")
print("   1. Uninstall current PyTorch: pip uninstall torch torchvision torchaudio -y")
print("   2. Install CUDA version: pip3 install torch torchvision --index-url https://download.pytorch.org/whl/cu130")
print("   3. Restart kernel and verify")
print("="*60)

# %% [markdown]
# ## 3. Complete System Information
#
# Gather all relevant system and package information.

# %%
import platform
import subprocess
import sys

print("💻 Complete System Information")
print("="*60)

# System info
print("\n🖥️  System:")
print(f"   OS: {platform.system()} {platform.release()}")
print(f"   Platform: {platform.platform()}")
print(f"   Architecture: {platform.machine()}")

# Python info
print("\n🐍 Python:")
print(f"   Version: {platform.python_version()}")
print(f"   Executable: {sys.executable}")
print(f"   Prefix: {sys.prefix}")

# GPU info
print("\n🎮 GPU Information:")
wmic_result = subprocess.run(
    ["wmic", "path", "win32_VideoController", "get", "name"],
    capture_output=True,
    text=True
)
if wmic_result.returncode == 0:
    lines = [l.strip() for l in wmic_result.stdout.split('\n') if l.strip() and l.strip() != 'Name']
    for gpu in lines:
        print(f"   {gpu}")

# PyTorch info
print("\n🔥 PyTorch:")
try:
    import torch
    print(f"   Version: {torch.__version__}")
    print(f"   CUDA Available: {torch.cuda.is_available()}")
    if torch.cuda.is_available():
        print(f"   CUDA Version: {torch.version.cuda}")
        print(f"   cuDNN Version: {torch.backends.cudnn.version()}")
        print(f"   GPU Count: {torch.cuda.device_count()}")
        for i in range(torch.cuda.device_count()):
            print(f"   GPU {i}: {torch.cuda.get_device_name(i)}")
            props = torch.cuda.get_device_properties(i)
            print(f"      Memory: {props.total_memory / 1024**3:.1f} GB")
            print(f"      Compute Capability: {props.major}.{props.minor}")
except ImportError:
    print("   Not installed")

print("\n" + "="*60)

# %% [markdown]
# ## 4. Quick CUDA Verification
#
# Simple test to verify CUDA is working.

# %%
import torch

print("🔍 Quick CUDA Test")
print("="*50)

if torch.cuda.is_available():
    # Create a tensor on GPU
    x = torch.rand(5, 3).cuda()
    print("✅ Successfully created tensor on GPU:")
    print(x)
    print(f"\nTensor device: {x.device}")
    print(f"Tensor type: {x.type()}")
    
    # Simple operation
    y = x * 2
    print("\n✅ GPU computation successful!")
    print(f"\n🚀 Your GPU ({torch.cuda.get_device_name(0)}) is ready for training!")
else:
    print("❌ CUDA not available. Tensor will be on CPU.")
    x = torch.rand(5, 3)
    print(x)
    print(f"\nTensor device: {x.device}")
    print("\n⚠️  GPU not configured. Review diagnostic outputs above.")

print("="*50)
